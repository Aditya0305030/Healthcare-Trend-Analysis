# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.common.exceptions import NoSuchElementException
import time,re
import pandas as pd

# %%
driver=webdriver.Chrome(service=Service(ChromeDriverManager().install()))

# %%
# search_categories = {
#     "Medical Research": ["clinical trial", "medical research", "peer-reviewed", "medical study", "cohort analysis"],
#     "Treatments": ["drug treatment", "therapy", "vaccine","treatment plan"],
#     "Disease Outbreaks": ["pandemic", "epidemic", "infectious disease"],
#     "Technology Advancements": ["AI in healthcare", "telemedicine", "robotic surgery", "medical devices"],
#     "Healthcare Investments": ["healthcare startup", "health investment", "biotech funding"]
# }

search_categories = {
    "Medical Research": [
        "clinical trial", "systematic review", "medical study", "observational study", "case-control study"
    ],
    "Treatments": [
        "drug therapy", "immunotherapy", "gene therapy", "precision medicine", "vaccine", "chemotherapy"
    ],
    "Disease Outbreaks": [
        "pandemic", "epidemic", "emerging infectious diseases", "zoonotic diseases", "public health emergency"
    ],
    "Technology Advancements": [
        "AI in healthcare", "robotic surgery", "telemedicine", "wearable medical devices", "digital health", "virtual care"
    ],
    "Healthcare Investments": [
        "healthcare startup", "biotech investment", "health innovation funding", "venture capital health", "digital health investment"
    ],
    "Chronic Diseases": [
        "diabetes management", "chronic heart failure", "chronic kidney disease", "COPD", "arthritis"
    ],
    "Mental Health": [
        "depression treatment", "mental health crisis", "anxiety disorder", "bipolar disorder", "teletherapy"
    ],
    "Genomics & Precision Medicine": [
        "CRISPR", "genome sequencing", "pharmacogenomics", "cancer genomics", "personalized medicine"
    ],
    "Public Health & Policy": [
        "health equity", "social determinants of health", "healthcare access", "universal health coverage", "health policy reform"
    ],
    "Environmental & Climate Health": [
        "climate change and health", "air pollution exposure", "environmental toxins", "heatwaves", "vector-borne disease"
    ]
}


def parse_citation(citation):
    journal = re.match(r"^([^.]+)\.", citation)
    journal = journal.group(1).strip() if journal else ""

    date = re.search(r"(\d{4})\s+([A-Za-z]{3})", citation)
    year = date.group(1) if date else ""
    month = date.group(2) if date else ""

    volume_pages = re.search(r";(\d+):([\d\-–]+)", citation)
    volume = volume_pages.group(1) if volume_pages else ""
    
    doi = re.search(r"doi:\s*([\w./-]+)", citation)
    doi = doi.group(1) if doi else ""

    return journal, year, month, volume, doi



max_pages = 3
all_data = []

for category, keywords in search_categories.items():
    for keyword in keywords:
        print(f"\n🔍 Scraping '{keyword}' under category '{category}'")
        base_url = f"https://pubmed.ncbi.nlm.nih.gov/?term={keyword.replace(' ', '+')}"
        driver.get(base_url)
        time.sleep(2)

        current_page = 1
        while current_page <= max_pages:
            print(f"  📄 Page {current_page}")
            time.sleep(2)

            articles = driver.find_elements(By.CLASS_NAME, 'docsum-content')
            for article in articles:
                try:
                    title = article.find_element(By.CLASS_NAME, 'docsum-title').text
                    citation = article.find_element(By.CLASS_NAME, 'docsum-journal-citation').text
                    journal, year, month, volume, doi = parse_citation(citation)
                    all_data.append({
                        "Category": category,
                        "Keyword": keyword,
                        "Title": title,
                        "Citation": citation,
                        "Journal": journal,
                        "Year": year,
                        "Month": month,
                        "Volume": volume,
                        "DOI": doi
                    })
                except Exception as e:
                    print("    ❌ Error extracting article:", e)

            try:
                # Find and click the next-page button
                next_button = driver.find_element(By.CLASS_NAME, 'next-page-btn')
                driver.execute_script("arguments[0].click();", next_button)
                current_page += 1
                time.sleep(2)
            except NoSuchElementException:
                print("    🚫 No more pages.")
                break
# Out:
# 🔍 Scraping 'clinical trial' under category 'Medical Research'
#   📄 Page 1
#   📄 Page 2
#   📄 Page 3
#
# 🔍 Scraping 'systematic review' under category 'Medical Research'
#   📄 Page 1
#   📄 Page 2
#   📄 Page 3
#
# 🔍 Scraping 'medical study' under category 'Medical Research'
#   📄 Page 1
#   📄 Page 2
#   📄 Page 3
#
# 🔍 Scraping 'observational study' under category 'Medical Research'
#   📄 Page 1
#   📄 Page 2
#   📄 Page 3
#
# 🔍 Scraping 'case-control study' under category 'Medical Research'
#   📄 Page 1
#   📄 Page 2
#   📄 Page 3
#
# 🔍 Scraping 'drug therapy' under category 'Treatments'
#   📄 Page 1
#   📄 Page 2
#   📄 Page 3
#
# 🔍 Scraping 'immunotherapy' under category 'Treatments'
#   📄 Page 1
#   📄 Page 2
#   📄 Page 3
#
# 🔍 Scraping 'gene therapy' under category 'Treatments'
#   📄 Page 1
#   📄 Page 2
#   📄 Page 3
#
# 🔍 Scraping 'precision medicine' under category 'Treatments'
#   📄 Page 1
#   📄 Page 2
#   📄 Page 3
#
# 🔍 Scraping 'vaccine' under category 'Treatments'
#   📄 Page 1
#   📄 Page 2
#   📄 Page 3
#
# 🔍 Scraping 'chemotherapy' under category 'Treatments'
#   📄 Page 1
#   📄 Page 2
#   📄 Page 3
#
# 🔍 Scraping 'pandemic' under category 'Disease Outbreaks'
#   📄 Page 1
#   📄 Page 2
#   📄 Page 3
#
# 🔍 Scraping 'epidemic' under category 'Disease Outbreaks'
#   📄 Page 1
#   📄 Page 2
#   📄 Page 3
#
# 🔍 Scraping 'emerging infectious diseases' under category 'Disease Outbreaks'
#   📄 Page 1
#   📄 Page 2
#   📄 Page 3
#
# 🔍 Scraping 'zoonotic diseases' under category 'Disease Outbreaks'
#   📄 Page 1
#   📄 Page 2
#   📄 Page 3
#
# 🔍 Scraping 'public health emergency' under category 'Disease Outbreaks'
#   📄 Page 1
#   📄 Page 2
#   📄 Page 3
#
# 🔍 Scraping 'AI in healthcare' under category 'Technology Advancements'
#   📄 Page 1
#   📄 Page 2
#   📄 Page 3
#
# 🔍 Scraping 'robotic surgery' under category 'Technology Advancements'
#   📄 Page 1
#   📄 Page 2
#   📄 Page 3
#
# 🔍 Scraping 'telemedicine' under category 'Technology Advancements'
#   📄 Page 1
#   📄 Page 2
#   📄 Page 3
#
# 🔍 Scraping 'wearable medical devices' under category 'Technology Advancements'
#   📄 Page 1
#   📄 Page 2
#   📄 Page 3
#
# 🔍 Scraping 'digital health' under category 'Technology Advancements'
#   📄 Page 1
#   📄 Page 2
#   📄 Page 3
#
# 🔍 Scraping 'virtual care' under category 'Technology Advancements'
#   📄 Page 1
#   📄 Page 2
#   📄 Page 3
#
# 🔍 Scraping 'healthcare startup' under category 'Healthcare Investments'
#   📄 Page 1
#   📄 Page 2
#   📄 Page 3
#
# 🔍 Scraping 'biotech investment' under category 'Healthcare Investments'
#   📄 Page 1
#   📄 Page 2
#   📄 Page 3
#
# 🔍 Scraping 'health innovation funding' under category 'Healthcare Investments'
#   📄 Page 1
#   📄 Page 2
#   📄 Page 3
#
# 🔍 Scraping 'venture capital health' under category 'Healthcare Investments'
#   📄 Page 1
#   📄 Page 2
#   📄 Page 3
#
# 🔍 Scraping 'digital health investment' under category 'Healthcare Investments'
#   📄 Page 1
#   📄 Page 2
#   📄 Page 3
#
# 🔍 Scraping 'diabetes management' under category 'Chronic Diseases'
#   📄 Page 1
#   📄 Page 2
#   📄 Page 3
#
# 🔍 Scraping 'chronic heart failure' under category 'Chronic Diseases'
#   📄 Page 1
#   📄 Page 2
#   📄 Page 3
#
# 🔍 Scraping 'chronic kidney disease' under category 'Chronic Diseases'
#   📄 Page 1
#   📄 Page 2
#   📄 Page 3
#
# 🔍 Scraping 'COPD' under category 'Chronic Diseases'
#   📄 Page 1
#   📄 Page 2
#   📄 Page 3
#
# 🔍 Scraping 'arthritis' under category 'Chronic Diseases'
#   📄 Page 1
#   📄 Page 2
#   📄 Page 3
#
# 🔍 Scraping 'depression treatment' under category 'Mental Health'
#   📄 Page 1
#   📄 Page 2
#   📄 Page 3
#
# 🔍 Scraping 'mental health crisis' under category 'Mental Health'
#   📄 Page 1
#   📄 Page 2
#   📄 Page 3
#
# 🔍 Scraping 'anxiety disorder' under category 'Mental Health'
#   📄 Page 1
#   📄 Page 2
#   📄 Page 3
#
# 🔍 Scraping 'bipolar disorder' under category 'Mental Health'
#   📄 Page 1
#   📄 Page 2
#   📄 Page 3
#
# 🔍 Scraping 'teletherapy' under category 'Mental Health'
#   📄 Page 1
#   📄 Page 2
#   📄 Page 3
#
# 🔍 Scraping 'CRISPR' under category 'Genomics & Precision Medicine'
#   📄 Page 1
#   📄 Page 2
#   📄 Page 3
#
# 🔍 Scraping 'genome sequencing' under category 'Genomics & Precision Medicine'
#   📄 Page 1
#   📄 Page 2
#   📄 Page 3
#
# 🔍 Scraping 'pharmacogenomics' under category 'Genomics & Precision Medicine'
#   📄 Page 1
#   📄 Page 2
#   📄 Page 3
#
# 🔍 Scraping 'cancer genomics' under category 'Genomics & Precision Medicine'
#   📄 Page 1
#   📄 Page 2
#   📄 Page 3
#
# 🔍 Scraping 'personalized medicine' under category 'Genomics & Precision Medicine'
#   📄 Page 1
#   📄 Page 2
#   📄 Page 3
#
# 🔍 Scraping 'health equity' under category 'Public Health & Policy'
#   📄 Page 1
#   📄 Page 2
#   📄 Page 3
#
# 🔍 Scraping 'social determinants of health' under category 'Public Health & Policy'
#   📄 Page 1
#   📄 Page 2
#   📄 Page 3
#
# 🔍 Scraping 'healthcare access' under category 'Public Health & Policy'
#   📄 Page 1
#   📄 Page 2
#   📄 Page 3
#
# 🔍 Scraping 'universal health coverage' under category 'Public Health & Policy'
#   📄 Page 1
#   📄 Page 2
#   📄 Page 3
#
# 🔍 Scraping 'health policy reform' under category 'Public Health & Policy'
#   📄 Page 1
#   📄 Page 2
#   📄 Page 3
#
# 🔍 Scraping 'climate change and health' under category 'Environmental & Climate Health'
#   📄 Page 1
#   📄 Page 2
#   📄 Page 3
#
# 🔍 Scraping 'air pollution exposure' under category 'Environmental & Climate Health'
#   📄 Page 1
#   📄 Page 2
#   📄 Page 3
#
# 🔍 Scraping 'environmental toxins' under category 'Environmental & Climate Health'
#   📄 Page 1
#   📄 Page 2
#   📄 Page 3
#
# 🔍 Scraping 'heatwaves' under category 'Environmental & Climate Health'
#   📄 Page 1
#   📄 Page 2
#   📄 Page 3
#
# 🔍 Scraping 'vector-borne disease' under category 'Environmental & Climate Health'
#   📄 Page 1
#   📄 Page 2
#   📄 Page 3

# %%
driver.quit()

# %%
df = pd.DataFrame(all_data)

# %%
df.shape
# Out:
# (1560, 9)

# %%
df.head()
# Out:
#            Category         Keyword  \
# 0  Medical Research  clinical trial
# 1  Medical Research  clinical trial
# 2  Medical Research  clinical trial
# 3  Medical Research  clinical trial
# 4  Medical Research  clinical trial
#
#                                                Title  \
# 0          An introduction to clinical trial design.
# 1   Clinical Trial Considerations in Neuro-oncology.
# 2  Key concepts of clinical trials: a narrative r...
# 3  Organizing a clinical trial for the new invest...
# 4  SPIRIT 2013 statement: defining standard proto...
#
#                                             Citation  \
# 0  Paediatr Respir Rev. 2019 Nov;32:30-35. doi: 1...
# 1  Curr Treat Options Oncol. 2021 Jul 2;22(9):78....
# 2  Postgrad Med. 2011 Sep;123(5):194-204. doi: 10...
# 3  Urol Oncol. 2019 May;37(5):336-339. doi: 10.10...
# 4  Ann Intern Med. 2013 Feb 5;158(3):200-7. doi: ...
#
#                     Journal  Year Month Volume  \
# 0       Paediatr Respir Rev  2019   Nov     32
# 1  Curr Treat Options Oncol  2021   Jul
# 2              Postgrad Med  2011   Sep
# 3                Urol Oncol  2019   May
# 4            Ann Intern Med  2013   Feb
#
#                                         DOI
# 0               10.1016/j.prrv.2019.06.002.
# 1               10.1007/s11864-021-00875-8.
# 2                 10.3810/pgm.2011.09.2475.
# 3            10.1016/j.urolonc.2017.12.017.
# 4  10.7326/0003-4819-158-3-201302050-00583.

# %%
df.to_csv("pubmed_categorized_data.csv", index=False)
print(f"\n✅ Done. {len(df)} articles scraped and saved.")
# Out:
# ✅ Done. 1560 articles scraped and saved.
